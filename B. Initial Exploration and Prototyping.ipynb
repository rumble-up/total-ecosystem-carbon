# %% [markdown]
# # Initial Exploration and Prototyping
# This is the notebook I wrote initially to explore the data, troubleshoot, and prototype my pipeline before creating a python module. It stands as a basic record of the thought process I used.
#
# ## Assumptions
#
# Whenever I start a technical project, my preference is to have a conversation with the end user. Ideally, it's helpful to sit down and see what their current tools and work are so I can understand how this project fits into their work flow.  I prefer to sketch out together the database tables they need, or the visualizations they'd like to make and then work back to the table layout that supports the visualization.
#
# Since this is a coding challenge where no end user is described, here are some basic assumptions I made to start.
#
# * The end user is the backend team who want to populate an interactive map that shows the Total Ecosystem Carbon totalled for each county in Michigan, Wisconsin and Minnesota.  They need the data in a database format in order to populate their map.
# * They want to use the 2020 NFCMS data and do not need the 2050 or 2070 projected data.
# * Using county administrative boundaries from 2024 is acceptable.
# * An acceptable export CRS for the final database is `EPSG:4326`

# %%
import geopandas as gpd
import pandas as pd
#Raster stats is not the fastest or most scaleable way to do this, but it is simple.
from rasterstats import zonal_stats
import rasterio
import os
import sqlite3

# %% [markdown]
# # Set filenames and constants

# %%
raster_file = "data/inputs/NLS_TotalEcosystemCarbon2020.tif"
#I had some trouble reading the raster nodata value directly from the raster metadata, 
# so I looked it up in the documentation and hardcoded it for now
raster_nodata = 65535  
boundary_file = "data/inputs/US_census_counties/cb_2024_us_county_500k.shp"
export_crs = "EPSG:4326"    

SQ_M_IN_ACRE = 4046.86
SQ_M_IN_SQ_MILE = 2589988.11
# each pixel is 30m x 30m = 900 sq meters, this value adjusts the pixel from MgCO2e/acre to just MgCO2e
PIXEL_AREA_ADJUST = 900 / SQ_M_IN_ACRE

# %% [markdown]
# # Load raster and check values

# %%
# Open the raster file
with rasterio.open(raster_file) as src:
    # Read the first band as a numpy array
    raster_crs = src.crs.to_string()

    # raster_nodata = src.nodata
    # I could not get src.nodata to work properly with this raster, so I hardcoded it in the constants

# %% [markdown]
# # Load Polygon Boundaries, Then Narrow to Michigan, Wisconsin, Minnesota

# %%
# Load polygon boundaries
gdf = gpd.read_file(boundary_file)
mask = gdf['STATE_NAME'].isin(['Michigan', 'Wisconsin', 'Minnesota'])

#Transform to raster CRS
gdf = gdf[mask].to_crs(raster_crs)

print(f"Raster CRS: {raster_crs}")
print(f"Polygon CRS: {gdf.crs}")
print(gdf['STATE_NAME'].value_counts())
gdf.head()
# Out:
# Raster CRS: EPSG:5070
# Polygon CRS: EPSG:5070
# STATE_NAME
# Minnesota    87
# Michigan     83
# Wisconsin    72
# Name: count, dtype: int64
#    STATEFP COUNTYFP  COUNTYNS         GEOIDFQ  GEOID       NAME  \
# 30      27      087  00659488  0500000US27087  27087   Mahnomen
# 38      27      053  00659472  0500000US27053  27053   Hennepin
# 66      26      103  01622994  0500000US26103  26103  Marquette
# 67      26      053  01622969  0500000US26053  26053    Gogebic
# 68      26      115  01623000  0500000US26115  26115     Monroe
#
#             NAMELSAD STUSPS STATE_NAME LSAD       ALAND      AWATER  \
# 30   Mahnomen County     MN  Minnesota   06  1444868083    64851532
# 38   Hennepin County     MN  Minnesota   06  1434901813   136571331
# 66  Marquette County     MI   Michigan   06  4685463544  4185295221
# 67    Gogebic County     MI   Michigan   06  2854517947   970153215
# 68     Monroe County     MI   Michigan   06  1422841177   338180469
#
#                                              geometry
# 30  POLYGON ((-5127.48 2722880.903, -1879.895 2722...
# 38  POLYGON ((175982.379 2437263.302, 175971.634 2...
# 66  MULTIPOLYGON (((659980.485 2652567.064, 660027...
# 67  POLYGON ((429071.487 2632246.414, 429346.073 2...
# 68  POLYGON ((1001838.421 2184665.346, 1006877.235...

# %%
print(f"There are {len(gdf)} counties in MI, WI, and MN.")
print(f"So only attributes with {len(gdf)} unique values are unique identifiers.")
print('Here are the counts of unique values for each attribute:')
print(gdf.nunique())
print("")
print("For now I'll select GEOID as the unique identifier for each county.")
# Out:
# There are 242 counties in MI, WI, and MN.
# So only attributes with 242 unique values are unique identifiers.
# Here are the counts of unique values for each attribute:
# STATEFP         3
# COUNTYFP       88
# COUNTYNS      242
# GEOIDFQ       242
# GEOID         242
# NAME          223
# NAMELSAD      223
# STUSPS          3
# STATE_NAME      3
# LSAD            1
# ALAND         242
# AWATER        242
# geometry      242
# dtype: int64
#
# For now I'll select GEOID as the unique identifier for each county.

# %% [markdown]
# # Compute totals for each county from the raster
# This step takes the longest by far, about 1 minute on my computer.  `raster_stats.zonal_stats` is perhaps not the best choice for this task, but it works, so I'll leave it for now

# %%
# Compute the sum of raster values within each polygon
stats = zonal_stats(gdf, raster_file, stats=["sum"], nodata=raster_nodata)
gdf["raster_sum"] = [s["sum"] for s in stats]

print("Check to see that the raster sums are not null values:")
print("")
gdf.info()
# Out:
# Check to see that the raster sums are not null values:
#
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 242 entries, 30 to 3225
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STATEFP     242 non-null    object
#  1   COUNTYFP    242 non-null    object
#  2   COUNTYNS    242 non-null    object
#  3   GEOIDFQ     242 non-null    object
#  4   GEOID       242 non-null    object
#  5   NAME        242 non-null    object
#  6   NAMELSAD    242 non-null    object
#  7   STUSPS      242 non-null    object
#  8   STATE_NAME  242 non-null    object
#  9   LSAD        242 non-null    object
#  10  ALAND       242 non-null    int64
#  11  AWATER      242 non-null    int64
#  12  geometry    242 non-null    geometry
#  13  raster_sum  242 non-null    float64
# dtypes: float64(1), geometry(1), int64(2), object(10)
# memory usage: 28.4+ KB

# %%
gdf['Mg_CO2e'] = gdf['raster_sum'] * PIXEL_AREA_ADJUST
gdf['Tg_CO2e'] = gdf['Mg_CO2e'] / 1e6  # convert from Mg to Tg
gdf['county_area_sq_miles'] = gdf.geometry.area / SQ_M_IN_SQ_MILE  # convert from sq meters to sq miles
gdf['county_area_acres'] = gdf.geometry.area / SQ_M_IN_ACRE  # convert from sq meters to acres
gdf['average_Mg_CO2e_per_acre'] = gdf['Mg_CO2e'] / gdf['county_area_acres']

gdf.head(2)
# Out:
#    STATEFP COUNTYFP  COUNTYNS         GEOIDFQ  GEOID      NAME  \
# 30      27      087  00659488  0500000US27087  27087  Mahnomen
# 38      27      053  00659472  0500000US27053  27053  Hennepin
#
#            NAMELSAD STUSPS STATE_NAME LSAD       ALAND     AWATER  \
# 30  Mahnomen County     MN  Minnesota   06  1444868083   64851532
# 38  Hennepin County     MN  Minnesota   06  1434901813  136571331
#
#                                              geometry   raster_sum  \
# 30  POLYGON ((-5127.48 2722880.903, -1879.895 2722...  120891547.0
# 38  POLYGON ((175982.379 2437263.302, 175971.634 2...   46142351.0
#
#          Mg_CO2e    Tg_CO2e  county_area_sq_miles  county_area_acres  \
# 30  2.688563e+07  26.885633            582.895399      373052.725722
# 38  1.026181e+07  10.261812            606.767146      388330.629817
#
#     average_Mg_CO2e_per_acre
# 30                 72.069257
# 38                 26.425451

# %% [markdown]
# # Create histogram of totals and validate against statistics in QGIS

# %%
# Look at histograms to check values and validate against statistics in QGIS
gdf[['average_Mg_CO2e_per_acre', 'Tg_CO2e']].hist(bins=30, figsize=(6, 3))
# Out:
# array([[<Axes: title={'center': 'average_Mg_CO2e_per_acre'}>,
#         <Axes: title={'center': 'Tg_CO2e'}>]], dtype=object)

# %%
gdf.sort_values('average_Mg_CO2e_per_acre', ascending=False).head(3)
# Out:
#      STATEFP COUNTYFP  COUNTYNS         GEOIDFQ  GEOID       NAME  \
# 466       55      078  01581099  0500000US55078  55078  Menominee
# 67        26      053  01622969  0500000US26053  26053    Gogebic
# 3109      26      131  01623008  0500000US26131  26131  Ontonagon
#
#               NAMELSAD STUSPS STATE_NAME LSAD       ALAND      AWATER  \
# 466   Menominee County     WI  Wisconsin   06   926217566    19022479
# 67      Gogebic County     MI   Michigan   06  2854517947   970153215
# 3109  Ontonagon County     MI   Michigan   06  3395416358  6292279244
#
#                                                geometry   raster_sum  \
# 466   POLYGON ((551112.773 2479206.629, 551536.245 2...  263030932.0
# 67    POLYGON ((429071.487 2632246.414, 429346.073 2...  708578985.0
# 3109  POLYGON ((468549.074 2656807.415, 471110.325 2...  785932462.0
#
#            Mg_CO2e     Tg_CO2e  county_area_sq_miles  county_area_acres  \
# 466   5.849667e+07   58.496671            364.997494      233598.189479
# 67    1.575842e+08  157.584173           1143.814322      732040.519146
# 3109  1.747872e+08  174.787172           1327.648617      849694.363893
#
#       average_Mg_CO2e_per_acre
# 466                 250.415773
# 67                  215.267009
# 3109                205.705933

# %% [markdown]
# #  Select Columns for Database and Export to Sqlite

# %%
keep_cols = ['GEOID', 'NAME', 'STATE_NAME', 'Tg_CO2e', 'average_Mg_CO2e_per_acre', 'county_area_acres', 'geometry'] 

gdf_for_sql = gdf[keep_cols].to_crs(export_crs)
gdf_for_sql.head(2)
# Out:
#     GEOID      NAME STATE_NAME    Tg_CO2e  average_Mg_CO2e_per_acre  \
# 30  27087  Mahnomen  Minnesota  26.885633                 72.069257
# 38  27053  Hennepin  Minnesota  10.261812                 26.425451
#
#     county_area_acres                                           geometry
# 30      373052.725722  POLYGON ((-96.06762 47.49914, -96.02479 47.499...
# 38      388330.629817  POLYGON ((-93.76804 44.90544, -93.76794 44.912...

# %% [markdown]
# ## Clean dataframe for a database

# %%
# Prepare a DB-friendly table: convert geometry to WKT and drop original geometry column
df = gdf_for_sql.drop(columns="geometry").copy()
geom_column_name = f"geometry_wkt_{export_crs.replace(':', '_')}"

df[geom_column_name] = gdf_for_sql.geometry.to_wkt()
rename_cols = {'GEOID': 'geoid', 
               'NAME': 'county_name', 
               'STATE_NAME': 'state_name', 
               'Tg_CO2e': 'total_Tg_CO2e', 
               }
df = df.rename(columns=rename_cols)

df.head(2)
# Out:
#     geoid county_name state_name  total_Tg_CO2e  average_Mg_CO2e_per_acre  \
# 30  27087    Mahnomen  Minnesota      26.885633                 72.069257
# 38  27053    Hennepin  Minnesota      10.261812                 26.425451
#
#     county_area_acres                             geometry_wkt_EPSG_4326
# 30      373052.725722  POLYGON ((-96.067621 47.499136, -96.024792 47....
# 38      388330.629817  POLYGON ((-93.768043 44.905436, -93.76794 44.9...

# %%
out_db = "data/outputs/county_carbon.sqlite"
os.makedirs(os.path.dirname(out_db), exist_ok=True)

# Write to SQLite
conn = sqlite3.connect(out_db)
df.to_sql("county_carbon", conn, if_exists="replace", index=False)
conn.close()

print(f"Exported {len(df)} rows to {out_db} (table: county_carbon).")
# Out:
# Exported 242 rows to data/outputs/county_carbon.sqlite (table: county_carbon).

# %% [markdown]
# # Example SQL queries

# %%
# Example SQL query to read data back into a GeoDataFrame

#Connect to SQLite database file
conn = sqlite3.connect("data/outputs/county_carbon.sqlite")

# Query all columns for Minnesota counties with more than 6 Tg CO2e
query = """
SELECT *
FROM county_carbon
WHERE state_name = 'Minnesota'
  AND total_Tg_CO2e > 6;
"""

# Use pandas to execute query and load into DataFrame
df_from_sql = pd.read_sql_query(query, conn)

# Close the connection
conn.close()
# Transform df to a GeoDataFrame

gdf_from_sql = gpd.GeoDataFrame(
    df_from_sql,
    geometry=gpd.GeoSeries.from_wkt(df_from_sql['geometry_wkt_EPSG_4326']),
    crs='EPSG:4326'
)
gdf_from_sql = gdf_from_sql.drop(columns='geometry_wkt_EPSG_4326')

# Output the GeoDataFrame to verify
gdf_from_sql.head()
# Out:
#    geoid county_name state_name  total_Tg_CO2e  average_Mg_CO2e_per_acre  \
# 0  27087    Mahnomen  Minnesota      26.885633                 72.069257
# 1  27053    Hennepin  Minnesota      10.261812                 26.425451
# 2  27075        Lake  Minnesota     209.668289                143.195233
# 3  27163  Washington  Minnesota      15.468979                 57.073777
# 4  27015       Brown  Minnesota       7.272261                 18.378212
#
#    county_area_acres                                           geometry
# 0       3.730527e+05  POLYGON ((-96.06762 47.49914, -96.02479 47.499...
# 1       3.883306e+05  POLYGON ((-93.76804 44.90544, -93.76794 44.912...
# 2       1.464213e+06  MULTIPOLYGON (((-91.55375 47.08965, -91.55327 ...
# 3       2.710348e+05  POLYGON ((-93.0214 44.78971, -93.02035 44.7942...
# 4       3.957001e+05  POLYGON ((-95.10878 44.19504, -95.10748 44.281...
